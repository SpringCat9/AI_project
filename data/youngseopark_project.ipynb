# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import Model, layers
from glob import glob
from PIL import Image
import os
import zipfile
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras.models import Sequential

# %%
# !nvidia-smi
# Out:
# Tue Jun  7 07:20:49 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 440.82       CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 108...  Off  | 00000000:03:00.0 Off |                  N/A |
# | 35%   60C    P8    13W / 250W |  10561MiB / 11176MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 108...  Off  | 00000000:04:00.0 Off |                  N/A |
# | 68%   79C    P2    74W / 250W |  10728MiB / 11178MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# GPU 할당 상태 확인

tf.test.is_gpu_available()
# Out:
# True

# %%
# !unzip -uq 'test-20220603T000915Z-001.zip' -d 'test'

# %%
# !unzip -uq 'train-20220603T000944Z-001.zip' -d 'train'

# %%
# !unzip -uq 'valid-20220603T000946Z-001.zip' -d 'valid'

# %%
# 데이터 packing

image_dates_train_nak = glob('./train/1*.jpg')
image_dates_train_scub = glob('./train/2*.jpg')
image_dates_train_oster = glob('./train/3*.jpg')

image_dates_valid_nak = glob('./valid/1*.jpg')
image_dates_valid_scub = glob('./valid/2*.jpg')
image_dates_valid_oster = glob('./valid/3*.jpg')

image_dates_test_nak = glob('./test/1*.jpg')
image_dates_test_scub = glob('./test/2*.jpg')
image_dates_test_oster = glob('./test/3*.jpg')

class_name = ['nacksungdae','scubhome', 'osteria']
dic = {'nacksungdae' : 0, 'scubhome' : 1, 'osteria' : 2}

# %%
X_train = []
Y_train = []
X_valid = []
Y_valid = []
X_test = []
Y_test = []

for imagename in image_dates_train_nak:
    image = Image.open(imagename)
    #image = image.resize((imagesize_w, imagesize_h))
    image = np.array(image)
    X_train.append(image)
    Y_train.append(0)
    
for imagename in image_dates_train_scub:
    image = Image.open(imagename)
    #image = image.resize((imagesize_w, imagesize_h))
    image = np.array(image)
    X_train.append(image)
    Y_train.append(1)    
    
for imagename in image_dates_train_oster:
    image = Image.open(imagename)
    #image = image.resize((imagesize_w, imagesize_h))
    image = np.array(image)
    X_train.append(image)
    Y_train.append(2)
    
for imagename in image_dates_valid_nak:
    image = Image.open(imagename)
    #image = image.resize((imagesize_w, imagesize_h))
    image = np.array(image)
    X_valid.append(image)
    Y_valid.append(0)
    
for imagename in image_dates_valid_scub:
    image = Image.open(imagename)
    #image = image.resize((imagesize_w, imagesize_h))
    image = np.array(image)
    X_valid.append(image)
    Y_valid.append(1)    
    
for imagename in image_dates_valid_oster:
    image = Image.open(imagename)
    #image = image.resize((imagesize_w, imagesize_h))
    image = np.array(image)
    X_valid.append(image)
    Y_valid.append(2)
    
for imagename in image_dates_test_nak:
    image = Image.open(imagename)
    #image = image.resize((imagesize_w, imagesize_h))
    image = np.array(image)
    X_test.append(image)
    Y_test.append(0)
    
for imagename in image_dates_test_scub:
    image = Image.open(imagename)
    #image = image.resize((imagesize_w, imagesize_h))
    image = np.array(image)
    X_test.append(image)
    Y_test.append(1)    
    
for imagename in image_dates_test_oster:
    image = Image.open(imagename)
    #image = image.resize((imagesize_w, imagesize_h))
    image = np.array(image)
    X_test.append(image)
    Y_test.append(2)
    
X_train = np.array(X_train)
Y_train = np.array(Y_train)
X_valid = np.array(X_valid)
Y_valid = np.array(Y_valid)
X_test = np.array(X_test)
Y_test = np.array(Y_test)

print(X_train.shape, Y_train.shape)
print(X_valid.shape, Y_valid.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (9180, 200, 200, 3) (9180,)
# (3060, 200, 200, 3) (3060,)
# (3060, 200, 200, 3) (3060,)

# %%
# train_images, test_images, train_labels, test_labels = train_test_split(X, Y, test_size = 0.2, shuffle = True, random_state = 44)

# print(train_images.shape, test_images.shape)
# print(train_labels.shape, test_labels.shape)
# %matplotlib inline 
N_TRAIN = X_train.shape[0]
N_TEST = X_valid.shape[0]

plt.figure(figsize = (15, 9))

# train data image 확인

for i in range(15):
    img_idx = np.random.randint(0, N_TRAIN)
    plt.subplot(3, 5, i+1)
    plt.xticks([])
    plt.yticks([])    
    plt.grid(False)
    plt.imshow(X_train[img_idx])
    plt.xlabel(class_name[Y_train[img_idx]])

# %%
#데이터 클래스가 잘 나뉘었는지 확인

unique, counts = np.unique(np.reshape(Y_train, (N_TRAIN,)), axis = -1, return_counts = True)
dict(zip(unique, counts))
# Out:
# {0: 3060, 1: 3060, 2: 3060}

# %%
#min-max scaling

X_train = X_train.astype(np.float32) / 255
X_valid = X_valid.astype(np.float32) / 255
X_test = X_test.astype(np.float32) / 255

x_train = X_train.reshape(-1, 200, 200, 3)
x_valid = X_valid.reshape(-1, 200, 200, 3)
x_test = X_test.reshape(-1, 200, 200, 3)

y_train = Y_train
y_test = Y_test
y_valid = Y_valid


print('train data : X ', x_train.shape, ' Y ', y_train.shape)
print('valid data : X ', x_valid.shape, ' Y ', y_valid.shape)
print('test data : X ', x_test.shape, ' Y ', y_test.shape)
# Out:
# train data : X  (9180, 200, 200, 3)  Y  (9180,)
# valid data : X  (3060, 200, 200, 3)  Y  (3060,)
# test data : X  (3060, 200, 200, 3)  Y  (3060,)

# %% [markdown]
# ## Model 1(CNN 실습코드)

# %%
data = [x_train, y_train, x_valid, y_valid, x_test, y_test]

def train(model, x_train, y_train, x_valid, y_valid, x_test, y_test, epoch = 100, lr = 0.1):
    model.compile(loss = 'sparse_categorical_crossentropy', optimizer = tf.keras.optimizers.SGD(learning_rate=lr), metrics = ['accuracy'])
    result = model.fit(x_train, y_train, epochs = epoch, batch_size = 128, validation_data = (x_valid, y_valid))
    test_result = cnn.evaluate(x_test, y_test)

    # show the learning curve
    plt.plot(result.history['accuracy'])
    plt.plot(result.history['val_accuracy'])
    plt.title('CNN ACCURACY')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.grid()
    plt.legend(['train','validation'], loc = 'best')

# %%
class CNN(Model):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = layers.Conv2D(32, 3, strides=1, padding='same', activation='relu', input_shape=(200, 200, 3))
        self.maxpool1 = layers.MaxPool2D(3, strides=2, padding='same')
        self.conv2 = layers.Conv2D(64, 3, strides=1, padding='same', activation='relu')
        self.maxpool2 = layers.MaxPool2D(3, strides=2, padding='same')
        self.flatten = layers.Flatten()
        self.fc1 = layers.Dense(128, activation='relu')
        self.fc2 = layers.Dense(3, activation='softmax')
        

    def call(self, x):
        x = self.conv1(x)
        x = self.maxpool1(x)
        x = self.conv2(x)
        x = self.maxpool2(x)
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.fc2(x)

        return x

# %%
cnn = CNN()
train(cnn, *data)
# Out:
# Epoch 1/100
# 72/72 [==============================] - 8s 110ms/step - loss: 1.1197 - accuracy: 0.4022 - val_loss: 1.0895 - val_accuracy: 0.3990
# Epoch 2/100
# 72/72 [==============================] - 7s 97ms/step - loss: 1.0841 - accuracy: 0.3886 - val_loss: 1.0879 - val_accuracy: 0.3503
# Epoch 3/100
# 72/72 [==============================] - 7s 97ms/step - loss: 1.0803 - accuracy: 0.4171 - val_loss: 1.0900 - val_accuracy: 0.3402
# Epoch 4/100
# 72/72 [==============================] - 7s 97ms/step - loss: 1.1405 - accuracy: 0.3928 - val_loss: 1.0459 - val_accuracy: 0.5147
# Epoch 5/100
# 72/72 [==============================] - 7s 98ms/step - loss: 1.0644 - accuracy: 0.4326 - val_loss: 1.0178 - val_accuracy: 0.5487
# Epoch 6/100
# 72/72 [==============================] - 7s 98ms/step - loss: 0.9399 - accuracy: 0.5347 - val_loss: 0.8124 - val_accuracy: 0.6516
# Epoch 7/100
# 72/72 [==============================] - 7s 97ms/step - loss: 1.0149 - accuracy: 0.4302 - val_loss: 1.0968 - val_accuracy: 0.3333
# Epoch 8/100
# 72/72 [==============================] - 7s 97ms/step - loss: 1.0950 - accuracy: 0.3605 - val_loss: 1.1017 - val_accuracy: 0.3346
# Epoch 9/100
# 72/72 [==============================] - 7s 98ms/step - loss: 1.0639 - accuracy: 0.4392 - val_loss: 0.9799 - val_accuracy: 0.5925
# Epoch 10/100
# 72/72 [==============================] - 7s 98ms/step - loss: 1.0466 - accuracy: 0.4613 - val_loss: 0.9179 - val_accuracy: 0.5275
# Epoch 11/100
# 72/72 [==============================] - 7s 98ms/step - loss: 1.0397 - accuracy: 0.4474 - val_loss: 1.1360 - val_accuracy: 0.3686
# Epoch 12/100
# 72/72 [==============================] - 7s 99ms/step - loss: 0.9763 - accuracy: 0.5117 - val_loss: 0.9120 - val_accuracy: 0.5752
# Epoch 13/100
# 72/72 [==============================] - 7s 98ms/step - loss: 0.9249 - accuracy: 0.5525 - val_loss: 0.9007 - val_accuracy: 0.5742
# Epoch 14/100
# 72/72 [==============================] - 7s 98ms/step - loss: 0.8494 - accuracy: 0.6146 - val_loss: 0.8904 - val_accuracy: 0.5820
# Epoch 15/100
# 72/72 [==============================] - 7s 98ms/step - loss: 0.7937 - accuracy: 0.6511 - val_loss: 1.0578 - val_accuracy: 0.5503
# Epoch 16/100
# 72/72 [==============================] - 7s 99ms/step - loss: 0.7396 - accuracy: 0.6767 - val_loss: 0.8693 - val_accuracy: 0.6497
# Epoch 17/100
# 72/72 [==============================] - 7s 99ms/step - loss: 0.6901 - accuracy: 0.6983 - val_loss: 0.9639 - val_accuracy: 0.6010
# Epoch 18/100
# 72/72 [==============================] - 7s 99ms/step - loss: 0.6532 - accuracy: 0.7188 - val_loss: 0.8281 - val_accuracy: 0.6523
# Epoch 19/100
# 72/72 [==============================] - 7s 99ms/step - loss: 0.5260 - accuracy: 0.7881 - val_loss: 0.7460 - val_accuracy: 0.7108
# Epoch 20/100
# 72/72 [==============================] - 7s 99ms/step - loss: 0.5445 - accuracy: 0.7861 - val_loss: 0.8604 - val_accuracy: 0.6552
# Epoch 21/100
# 72/72 [==============================] - 7s 99ms/step - loss: 0.5170 - accuracy: 0.7992 - val_loss: 0.7914 - val_accuracy: 0.6768
# Epoch 22/100
# 72/72 [==============================] - 7s 99ms/step - loss: 0.5130 - accuracy: 0.7935 - val_loss: 0.8334 - val_accuracy: 0.6716
# Epoch 23/100
# 72/72 [==============================] - 7s 99ms/step - loss: 0.3609 - accuracy: 0.8641 - val_loss: 0.8371 - val_accuracy: 0.6908
# Epoch 24/100
# 72/72 [==============================] - 7s 98ms/step - loss: 0.2815 - accuracy: 0.8972 - val_loss: 0.9810 - val_accuracy: 0.6817
# Epoch 25/100
# 72/72 [==============================] - 7s 99ms/step - loss: 0.1656 - accuracy: 0.9458 - val_loss: 1.0161 - val_accuracy: 0.6853
# Epoch 26/100
# 72/72 [==============================] - 7s 99ms/step - loss: 0.6477 - accuracy: 0.7052 - val_loss: 1.1005 - val_accuracy: 0.3199
# Epoch 27/100
# 72/72 [==============================] - 7s 99ms/step - loss: 1.0998 - accuracy: 0.3314 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 28/100
# 72/72 [==============================] - 7s 99ms/step - loss: 1.0997 - accuracy: 0.3215 - val_loss: 1.0999 - val_accuracy: 0.3333
# Epoch 29/100
# 72/72 [==============================] - 7s 100ms/step - loss: 1.0987 - accuracy: 0.3397 - val_loss: 1.1018 - val_accuracy: 0.3333
# Epoch 30/100
# 72/72 [==============================] - 7s 99ms/step - loss: 1.0989 - accuracy: 0.3403 - val_loss: 1.0992 - val_accuracy: 0.3333
# Epoch 31/100
# 72/72 [==============================] - 7s 99ms/step - loss: 1.0989 - accuracy: 0.3304 - val_loss: 1.0986 - val_accuracy: 0.3356
# Epoch 32/100
# 72/72 [==============================] - 7s 99ms/step - loss: 1.0989 - accuracy: 0.3338 - val_loss: 1.0990 - val_accuracy: 0.3363
# Epoch 33/100
# 72/72 [==============================] - 7s 98ms/step - loss: 1.0984 - accuracy: 0.3390 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 34/100
# 72/72 [==============================] - 7s 99ms/step - loss: 1.0984 - accuracy: 0.3355 - val_loss: 1.0986 - val_accuracy: 0.3343
# Epoch 35/100
# 72/72 [==============================] - 7s 99ms/step - loss: 1.0982 - accuracy: 0.3359 - val_loss: 1.0989 - val_accuracy: 0.3337
# Epoch 36/100
# 72/72 [==============================] - 7s 99ms/step - loss: 1.0980 - accuracy: 0.3426 - val_loss: 1.0994 - val_accuracy: 0.3402
# Epoch 37/100
# 72/72 [==============================] - 7s 99ms/step - loss: 1.0975 - accuracy: 0.3435 - val_loss: 1.0979 - val_accuracy: 0.3719
# Epoch 38/100
# 72/72 [==============================] - 7s 99ms/step - loss: 1.0958 - accuracy: 0.3423 - val_loss: 1.0959 - val_accuracy: 0.3529
# Epoch 39/100
# 72/72 [==============================] - 7s 99ms/step - loss: 1.0928 - accuracy: 0.3509 - val_loss: 1.0913 - val_accuracy: 0.3350
# Epoch 40/100
# 72/72 [==============================] - 7s 99ms/step - loss: 1.0760 - accuracy: 0.3865 - val_loss: 1.0801 - val_accuracy: 0.4500
# Epoch 41/100
# 72/72 [==============================] - 7s 99ms/step - loss: 1.0810 - accuracy: 0.3903 - val_loss: 1.0877 - val_accuracy: 0.3644
# Epoch 42/100
# 72/72 [==============================] - 7s 99ms/step - loss: 1.0734 - accuracy: 0.3868 - val_loss: 1.0678 - val_accuracy: 0.3853
# Epoch 43/100
# 72/72 [==============================] - 7s 98ms/step - loss: 1.0529 - accuracy: 0.4097 - val_loss: 1.0587 - val_accuracy: 0.3951
# Epoch 44/100
# 72/72 [==============================] - 7s 99ms/step - loss: 1.0333 - accuracy: 0.4185 - val_loss: 1.0500 - val_accuracy: 0.4163
# Epoch 45/100
# 72/72 [==============================] - 7s 100ms/step - loss: 1.0087 - accuracy: 0.4496 - val_loss: 1.0380 - val_accuracy: 0.4592
# Epoch 46/100
# 72/72 [==============================] - 7s 99ms/step - loss: 0.9034 - accuracy: 0.5693 - val_loss: 1.0111 - val_accuracy: 0.5846
# Epoch 47/100
# 72/72 [==============================] - 7s 99ms/step - loss: 0.6950 - accuracy: 0.7130 - val_loss: 0.9090 - val_accuracy: 0.6405
# Epoch 48/100
# 72/72 [==============================] - 7s 100ms/step - loss: 0.4183 - accuracy: 0.8471 - val_loss: 1.0130 - val_accuracy: 0.6693
# Epoch 49/100
# 72/72 [==============================] - 7s 99ms/step - loss: 0.2484 - accuracy: 0.9154 - val_loss: 1.1735 - val_accuracy: 0.6745
# Epoch 50/100
# 72/72 [==============================] - 7s 100ms/step - loss: 0.2769 - accuracy: 0.9127 - val_loss: 1.2670 - val_accuracy: 0.6562
# Epoch 51/100
# 72/72 [==============================] - 7s 100ms/step - loss: 0.2996 - accuracy: 0.9071 - val_loss: 1.1069 - val_accuracy: 0.6330
# Epoch 52/100
# 72/72 [==============================] - 7s 101ms/step - loss: 0.3350 - accuracy: 0.9037 - val_loss: 1.2520 - val_accuracy: 0.6310
# Epoch 53/100
# 72/72 [==============================] - 7s 99ms/step - loss: 0.1110 - accuracy: 0.9660 - val_loss: 1.2671 - val_accuracy: 0.6663
# Epoch 54/100
# 72/72 [==============================] - 7s 100ms/step - loss: 0.0427 - accuracy: 0.9913 - val_loss: 1.6546 - val_accuracy: 0.6739
# Epoch 55/100
# 72/72 [==============================] - 7s 100ms/step - loss: 0.0190 - accuracy: 0.9955 - val_loss: 1.8095 - val_accuracy: 0.6778
# Epoch 56/100
# 72/72 [==============================] - 7s 100ms/step - loss: 0.0121 - accuracy: 0.9977 - val_loss: 1.9729 - val_accuracy: 0.6781
# Epoch 57/100
# 72/72 [==============================] - 7s 100ms/step - loss: 0.0085 - accuracy: 0.9985 - val_loss: 2.1159 - val_accuracy: 0.6778
# Epoch 58/100
# 72/72 [==============================] - 7s 100ms/step - loss: 0.0065 - accuracy: 0.9991 - val_loss: 2.1988 - val_accuracy: 0.6781
# Epoch 59/100
# 72/72 [==============================] - 7s 101ms/step - loss: 0.0050 - accuracy: 0.9997 - val_loss: 2.3010 - val_accuracy: 0.6775
# Epoch 60/100
# 72/72 [==============================] - 7s 100ms/step - loss: 0.0040 - accuracy: 0.9998 - val_loss: 2.3754 - val_accuracy: 0.6814
# Epoch 61/100
# 72/72 [==============================] - 7s 101ms/step - loss: 0.0033 - accuracy: 0.9998 - val_loss: 2.4335 - val_accuracy: 0.6801
# Epoch 62/100
# 72/72 [==============================] - 7s 100ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 2.4981 - val_accuracy: 0.6833
# Epoch 63/100
# 72/72 [==============================] - 7s 100ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.5557 - val_accuracy: 0.6833
# Epoch 64/100
# 72/72 [==============================] - 7s 100ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 2.6047 - val_accuracy: 0.6833
# Epoch 65/100
# 72/72 [==============================] - 7s 100ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.6491 - val_accuracy: 0.6833
# Epoch 66/100
# 72/72 [==============================] - 7s 100ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 2.6824 - val_accuracy: 0.6827
# Epoch 67/100
# 72/72 [==============================] - 7s 99ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.7221 - val_accuracy: 0.6830
# Epoch 68/100
# 72/72 [==============================] - 7s 100ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.7545 - val_accuracy: 0.6824
# Epoch 69/100
# 72/72 [==============================] - 7s 100ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.7884 - val_accuracy: 0.6820
# Epoch 70/100
# 72/72 [==============================] - 7s 100ms/step - loss: 9.4089e-04 - accuracy: 1.0000 - val_loss: 2.8173 - val_accuracy: 0.6830
# Epoch 71/100
# 72/72 [==============================] - 7s 100ms/step - loss: 8.5574e-04 - accuracy: 1.0000 - val_loss: 2.8415 - val_accuracy: 0.6837
# Epoch 72/100
# 72/72 [==============================] - 7s 100ms/step - loss: 7.8200e-04 - accuracy: 1.0000 - val_loss: 2.8733 - val_accuracy: 0.6830
# Epoch 73/100
# 72/72 [==============================] - 7s 99ms/step - loss: 7.1896e-04 - accuracy: 1.0000 - val_loss: 2.8968 - val_accuracy: 0.6830
# Epoch 74/100
# 72/72 [==============================] - 7s 100ms/step - loss: 6.6190e-04 - accuracy: 1.0000 - val_loss: 2.9235 - val_accuracy: 0.6820
# Epoch 75/100
# 72/72 [==============================] - 7s 99ms/step - loss: 6.1509e-04 - accuracy: 1.0000 - val_loss: 2.9454 - val_accuracy: 0.6820
# Epoch 76/100
# 72/72 [==============================] - 7s 99ms/step - loss: 5.7303e-04 - accuracy: 1.0000 - val_loss: 2.9657 - val_accuracy: 0.6820
# Epoch 77/100
# 72/72 [==============================] - 7s 100ms/step - loss: 5.3315e-04 - accuracy: 1.0000 - val_loss: 2.9826 - val_accuracy: 0.6817
# Epoch 78/100
# 72/72 [==============================] - 7s 101ms/step - loss: 4.9967e-04 - accuracy: 1.0000 - val_loss: 3.0004 - val_accuracy: 0.6820
# Epoch 79/100
# 72/72 [==============================] - 7s 100ms/step - loss: 4.7022e-04 - accuracy: 1.0000 - val_loss: 3.0204 - val_accuracy: 0.6804
# Epoch 80/100
# 72/72 [==============================] - 7s 100ms/step - loss: 4.4285e-04 - accuracy: 1.0000 - val_loss: 3.0388 - val_accuracy: 0.6797
# Epoch 81/100
# 72/72 [==============================] - 7s 99ms/step - loss: 4.1847e-04 - accuracy: 1.0000 - val_loss: 3.0526 - val_accuracy: 0.6797
# Epoch 82/100
# 72/72 [==============================] - 7s 100ms/step - loss: 3.9605e-04 - accuracy: 1.0000 - val_loss: 3.0716 - val_accuracy: 0.6797
# Epoch 83/100
# 72/72 [==============================] - 7s 99ms/step - loss: 3.7547e-04 - accuracy: 1.0000 - val_loss: 3.0857 - val_accuracy: 0.6788
# Epoch 84/100
# 72/72 [==============================] - 7s 100ms/step - loss: 3.5725e-04 - accuracy: 1.0000 - val_loss: 3.1022 - val_accuracy: 0.6788
# Epoch 85/100
# 72/72 [==============================] - 7s 99ms/step - loss: 3.3996e-04 - accuracy: 1.0000 - val_loss: 3.1121 - val_accuracy: 0.6784
# Epoch 86/100
# 72/72 [==============================] - 7s 99ms/step - loss: 3.2367e-04 - accuracy: 1.0000 - val_loss: 3.1281 - val_accuracy: 0.6778
# Epoch 87/100
# 72/72 [==============================] - 7s 100ms/step - loss: 3.0920e-04 - accuracy: 1.0000 - val_loss: 3.1398 - val_accuracy: 0.6781
# Epoch 88/100
# 72/72 [==============================] - 7s 100ms/step - loss: 2.9598e-04 - accuracy: 1.0000 - val_loss: 3.1521 - val_accuracy: 0.6784
# Epoch 89/100
# 72/72 [==============================] - 7s 100ms/step - loss: 2.8319e-04 - accuracy: 1.0000 - val_loss: 3.1646 - val_accuracy: 0.6788
# Epoch 90/100
# 72/72 [==============================] - 7s 100ms/step - loss: 2.7140e-04 - accuracy: 1.0000 - val_loss: 3.1786 - val_accuracy: 0.6791
# Epoch 91/100
# 72/72 [==============================] - 7s 100ms/step - loss: 2.6097e-04 - accuracy: 1.0000 - val_loss: 3.1876 - val_accuracy: 0.6791
# Epoch 92/100
# 72/72 [==============================] - 7s 100ms/step - loss: 2.5065e-04 - accuracy: 1.0000 - val_loss: 3.1997 - val_accuracy: 0.6791
# Epoch 93/100
# 72/72 [==============================] - 7s 100ms/step - loss: 2.4165e-04 - accuracy: 1.0000 - val_loss: 3.2089 - val_accuracy: 0.6784
# Epoch 94/100
# 72/72 [==============================] - 7s 100ms/step - loss: 2.3269e-04 - accuracy: 1.0000 - val_loss: 3.2200 - val_accuracy: 0.6791
# Epoch 95/100
# 72/72 [==============================] - 7s 99ms/step - loss: 2.2447e-04 - accuracy: 1.0000 - val_loss: 3.2312 - val_accuracy: 0.6788
# Epoch 96/100
# 72/72 [==============================] - 7s 100ms/step - loss: 2.1688e-04 - accuracy: 1.0000 - val_loss: 3.2401 - val_accuracy: 0.6784
# Epoch 97/100
# 72/72 [==============================] - 7s 100ms/step - loss: 2.0944e-04 - accuracy: 1.0000 - val_loss: 3.2492 - val_accuracy: 0.6791
# Epoch 98/100
# 72/72 [==============================] - 7s 100ms/step - loss: 2.0287e-04 - accuracy: 1.0000 - val_loss: 3.2581 - val_accuracy: 0.6797
# Epoch 99/100
# 72/72 [==============================] - 7s 100ms/step - loss: 1.9609e-04 - accuracy: 1.0000 - val_loss: 3.2685 - val_accuracy: 0.6784
# Epoch 100/100
# 72/72 [==============================] - 7s 100ms/step - loss: 1.8991e-04 - accuracy: 1.0000 - val_loss: 3.2787 - val_accuracy: 0.6788
# 96/96 [==============================] - 1s 11ms/step - loss: 2.8814 - accuracy: 0.6843

# %%
# 학습 결과 labeling

for i in range(15):
    img_idx = np.random.randint(0, 3060)
    im = np.reshape(x_test[img_idx], (-1, 200, 200, 3))
    classnum = np.argmax(cnn.predict(im))
    plt.subplot(3, 5, i+1)
    plt.xticks([])
    plt.yticks([])    
    plt.grid(False)
    plt.imshow(x_test[img_idx])
    name = ''
    if classnum == 0 : name = 'naksung'
    elif classnum == 1 : name = 'scub'
    else : name = 'osteria'
    plt.xlabel(name)

# %% [markdown]
# ## Model 3(CNN 2)

# %%
def train(net, x_train, y_train, x_valid, y_valid, x_test, y_test, epochs = 5):
    optimizer = tf.keras.optimizers.SGD(learning_rate = 0.01)
    net.compile(loss = 'sparse_categorical_crossentropy',
                optimizer = optimizer,
                metrics = ['accuracy'])
    result = net.fit(x_train, y_train, epochs = epochs, batch_size = 128,
                     validation_data = (x_valid, y_valid), verbose = 1)
    
    plt.plot(result.history['accuracy'])
    plt.plot(result.history['val_accuracy'])
    plt.title('Accuracy')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.grid()
    plt.legend(['train', 'validation'], loc = 'best')
    plt.show()

def make_conv_block(num_filters, filter_size, stride, padding = 'same', input_shape = None):
    conv_block = Sequential()
    conv_block.add(layers.Conv2D(num_filters,
                                 filter_size,
                                 strides = stride,
                                 padding = padding,
                                 activation = 'relu'))
    
    conv_block.add(layers.Conv2D(num_filters,
                                 filter_size,
                                 strides = stride,
                                 padding = padding,
                                 activation = 'relu'))
    
    conv_block.add(layers.Conv2D(num_filters,
                                 filter_size,
                                 strides = stride,
                                 padding = padding,
                                 activation = 'relu'))
    
    return conv_block


class CNN(Model):
    def __init__(self, num_classes = 10):
        super(CNN, self).__init__()
        self.convblock1 = make_conv_block(32, 3, 1)
        self.bn1 = layers.BatchNormalization()
        self.convblock2 = make_conv_block(32, 3, 1)
        self.maxpool1 = layers.MaxPool2D(pool_size = 3,
                         strides = 2,
                         padding = 'same')
        
        self.convblock3 = make_conv_block(64, 3, 1)
        self.bn2 = layers.BatchNormalization()
        self.convblock4 = make_conv_block(64, 3, 1)
        self.maxpool2 = layers.MaxPool2D(pool_size = 3,
                         strides = 2,
                         padding = 'same')
        
        self.convblock5 = make_conv_block(32, 3, 1)
        self.bn3 = layers.BatchNormalization()
        self.convblock6 = make_conv_block(32, 3, 1)
        self.maxpool3 = layers.MaxPool2D(pool_size = 3,
                         strides = 2,
                         padding = 'same')
        
        self.flatten = layers.Flatten()
        
        self.fc1 = layers.Dense(128, activation = 'relu')
        self.fc2 = layers.Dense(64, activation = 'relu')
        
        self.fc3 = layers.Dense(num_classes, activation = 'softmax')
        
    
    def call(self, x):
        x = self.convblock1(x)
        x = self.bn1(x)
        x = self.convblock2(x)
        x = self.maxpool1(x)
        
        x = self.convblock3(x)
        x = self.bn2(x)
        x = self.convblock4(x)
        x = self.maxpool2(x)
        
        x = self.convblock5(x)
        x = self.bn3(x)
        x = self.convblock6(x)
        x = self.maxpool3(x)
        
        
        x = self.flatten(x)
        
        x = self.fc1(x)
        x = self.fc2(x)
        
        x = self.fc3(x)
        
        return x

# %%
data = [x_train, y_train, x_valid, y_valid, x_test, y_test]

# %%
cnn2 = CNN(num_classes = 3)
train(cnn2, *data, epochs = 20)

# %%
test_result = cnn2.evaluate(x_test, y_test)
print('test loss: ', test_result[0])
print('test acc: ', test_result[1])

# %%
# 학습 결과 labeling

for i in range(15):
    img_idx = np.random.randint(0, N_TRAIN)
    im = np.reshape(x_train[img_idx], (-1, 200, 200, 3))
    classnum = np.argmax(cnn.predict(im))
    plt.subplot(3, 5, i+1)
    plt.xticks([])
    plt.yticks([])    
    plt.grid(False)
    plt.imshow(x_train[img_idx])
    name = ''
    if classnum == 0 : name = 'naksung'
    elif classnum == 1 : name = 'scub'
    else : name = 'osteria'
    plt.xlabel(name)

# %% [markdown]
# ## Model 3(VGG16 Pretrained 모델)

# %%
from tensorflow.keras.applications import VGG16

vgg_base = VGG16(weights='imagenet',
                 include_top=False,        # class 3개로 분류 학습시켜야 해서 레이어 분리시킨 후, Desnse(3) 추가..?
                 input_shape=(200, 200, 3))

# %%
vgg_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 200, 200, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 200, 200, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 200, 200, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 100, 100, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 100, 100, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 100, 100, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 50, 50, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 50, 50, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 50, 50, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 50, 50, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 25, 25, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 25, 25, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 25, 25, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 25, 25, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 12, 12, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
model = models.Sequential()
model.add(vgg_base)
model.add(layers.Flatten())
model.add(layers.Dense(256, activation='relu'))
model.add(layers.Dense(3, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 6, 6, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               4718848
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 19,434,307
# Trainable params: 19,434,307
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = tf.keras.optimizers.SGD(learning_rate=2e-5),
              loss = 'sparse_categorical_crossentropy',
              metrics = ['acc'])

history = model.fit(x_train, y_train, epochs=30, batch_size=200, validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/30
#  2/46 [>.............................] - ETA: 34s - loss: 1.2159 - acc: 0.3350WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.4169s vs `on_train_batch_end` time: 1.1113s). Check your callbacks.
# 46/46 [==============================] - 83s 2s/step - loss: 1.1561 - acc: 0.3391 - val_loss: 1.1328 - val_acc: 0.3425
# Epoch 2/30
# 46/46 [==============================] - 79s 2s/step - loss: 1.1076 - acc: 0.3534 - val_loss: 1.1018 - val_acc: 0.3572
# Epoch 3/30
# 46/46 [==============================] - 79s 2s/step - loss: 1.0835 - acc: 0.3722 - val_loss: 1.0844 - val_acc: 0.3761
# Epoch 4/30
# 46/46 [==============================] - 79s 2s/step - loss: 1.0681 - acc: 0.4015 - val_loss: 1.0721 - val_acc: 0.4013
# Epoch 5/30
# 46/46 [==============================] - 79s 2s/step - loss: 1.0562 - acc: 0.4353 - val_loss: 1.0618 - val_acc: 0.4271
# Epoch 6/30
# 46/46 [==============================] - 79s 2s/step - loss: 1.0456 - acc: 0.4674 - val_loss: 1.0524 - val_acc: 0.4575
# Epoch 7/30
# 46/46 [==============================] - 79s 2s/step - loss: 1.0354 - acc: 0.4989 - val_loss: 1.0430 - val_acc: 0.4866
# Epoch 8/30
# 46/46 [==============================] - 79s 2s/step - loss: 1.0252 - acc: 0.5343 - val_loss: 1.0335 - val_acc: 0.5154
# Epoch 9/30
# 46/46 [==============================] - 79s 2s/step - loss: 1.0145 - acc: 0.5668 - val_loss: 1.0236 - val_acc: 0.5422
# Epoch 10/30
# 46/46 [==============================] - 79s 2s/step - loss: 1.0034 - acc: 0.5956 - val_loss: 1.0133 - val_acc: 0.5667
# Epoch 11/30
# 46/46 [==============================] - 79s 2s/step - loss: 0.9917 - acc: 0.6193 - val_loss: 1.0023 - val_acc: 0.5882
# Epoch 12/30
# 46/46 [==============================] - 79s 2s/step - loss: 0.9792 - acc: 0.6424 - val_loss: 0.9905 - val_acc: 0.6059
# Epoch 13/30
# 46/46 [==============================] - 79s 2s/step - loss: 0.9658 - acc: 0.6633 - val_loss: 0.9780 - val_acc: 0.6255
# Epoch 14/30
# 46/46 [==============================] - 79s 2s/step - loss: 0.9515 - acc: 0.6834 - val_loss: 0.9646 - val_acc: 0.6471
# Epoch 15/30
# 46/46 [==============================] - 79s 2s/step - loss: 0.9363 - acc: 0.7024 - val_loss: 0.9502 - val_acc: 0.6644
# Epoch 16/30
# 46/46 [==============================] - 79s 2s/step - loss: 0.9200 - acc: 0.7215 - val_loss: 0.9349 - val_acc: 0.6765
# Epoch 17/30
# 46/46 [==============================] - 79s 2s/step - loss: 0.9026 - acc: 0.7366 - val_loss: 0.9185 - val_acc: 0.6899
# Epoch 18/30
# 46/46 [==============================] - 79s 2s/step - loss: 0.8841 - acc: 0.7517 - val_loss: 0.9011 - val_acc: 0.7059
# Epoch 19/30
# 46/46 [==============================] - 79s 2s/step - loss: 0.8645 - acc: 0.7638 - val_loss: 0.8828 - val_acc: 0.7176
# Epoch 20/30
# 46/46 [==============================] - 79s 2s/step - loss: 0.8439 - acc: 0.7782 - val_loss: 0.8636 - val_acc: 0.7363
# Epoch 21/30
# 46/46 [==============================] - 79s 2s/step - loss: 0.8224 - acc: 0.7894 - val_loss: 0.8436 - val_acc: 0.7471
# Epoch 22/30
# 46/46 [==============================] - 80s 2s/step - loss: 0.8001 - acc: 0.8029 - val_loss: 0.8229 - val_acc: 0.7546
# Epoch 23/30
# 46/46 [==============================] - 79s 2s/step - loss: 0.7771 - acc: 0.8135 - val_loss: 0.8017 - val_acc: 0.7641
# Epoch 24/30
# 46/46 [==============================] - 79s 2s/step - loss: 0.7538 - acc: 0.8208 - val_loss: 0.7802 - val_acc: 0.7742
# Epoch 25/30
# 46/46 [==============================] - 79s 2s/step - loss: 0.7302 - acc: 0.8273 - val_loss: 0.7586 - val_acc: 0.7859
# Epoch 26/30
# 46/46 [==============================] - 79s 2s/step - loss: 0.7065 - acc: 0.8334 - val_loss: 0.7371 - val_acc: 0.7908
# Epoch 27/30
# 46/46 [==============================] - 79s 2s/step - loss: 0.6830 - acc: 0.8398 - val_loss: 0.7158 - val_acc: 0.7954
# Epoch 28/30
# 46/46 [==============================] - 79s 2s/step - loss: 0.6597 - acc: 0.8455 - val_loss: 0.6949 - val_acc: 0.8000
# Epoch 29/30
# 46/46 [==============================] - 79s 2s/step - loss: 0.6368 - acc: 0.8498 - val_loss: 0.6744 - val_acc: 0.8059
# Epoch 30/30
# 46/46 [==============================] - 79s 2s/step - loss: 0.6144 - acc: 0.8552 - val_loss: 0.6544 - val_acc: 0.8121

# %%
test_result = model.evaluate(x_test, y_test)
# Out:
# 96/96 [==============================] - 6s 63ms/step - loss: 0.6249 - acc: 0.8500

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('VGG16 ACCURACY')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.grid()
plt.legend(['train','validation'], loc = 'best')
